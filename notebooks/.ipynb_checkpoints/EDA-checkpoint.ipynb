# %% [markdown]
# # Data Driven Business Strategies using Iowa Spirits Sales

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Identified Business Problems

# %% [markdown]
# As presented in the previous notebook and in the Project proposal, we are using a large dataset to help stakeholders make data-driven business decisions. We identified a few avenues for explorations.
#
# In this EDA notebook, apart from our general Exploratory FEature Analysis(univariate, bivariate, multivariate) we will also answer 2 Business Problems:
#
# 1. We will conduct Exploratory Data Analysis on what was **the impact of Covid-19 on the Alcoholic Beverages Industry**. We will take into consideration the demographic trans and Income per capita, but we will also make our recommendations and analysis considering the “regression to the mean” statistical principle.
#
# 2. We will also conduct **Storage Capacity** exploratory analysis with the purpose of predicting how the storage needs will change within one year from the current date.
#
# Later, in our next Notebook we will approach another Business problems that concerns the Alcoholic Beverages Division of Iowa:
#
# 3. Cohort Analysis and **Customer Segmentation using RFM(Recency, Frequency and Monetary value) and Unsupervised Learning** in oru Pre-Processing section.
#
# Finally, in our Modeling Part, we will focus on driving Business Insight to help a hypothetical liquor store owner make strategic decisions:
#
# 4. We want to assist him in **expanding to new locations** throughout the state.
# 5. Lastly, we want to use existing data for a **time series analysis and predictions to forecast sales for next month**.

# %% [markdown]
# ### EDA setup

# %% [markdown]
# In the Data Wrangling part of this project we used our initial data and because of the large size we divided our initial data in several subset. Each of them to be used for specific Business problems. These are the datasets created:
# * pandemicEDA
# * storageEDA
# * cust_segmentation
# * pick_new_location
# * predict_sales
# * df - this is the original data, cleaned of missing data, ouliers and checked for consistency

# %% [markdown]
# We have this plan to conduct EDA:
#
#    1. Conduct univariate EDA on our data
#    2. Conduct bivariate EDA on variables with our target feature
#    3. Multivariate EDA
#    4. conduct Analysis of how Covid-19 impacted the Spirits Industry in Iowa
#    5. conduct Analysis on volume of alcoholic beverages sold within difeerent time periods: weekly, monthly and on a three months period to identify storage needs and trends.

# %% [markdown]
# ![1586552655_Step_3_colorful_group.png](attachment:1586552655_Step_3_colorful_group.png)

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)
import seaborn as sns
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Univariate Analysis

# %%
df = pd.read_csv('../data/interim/cleaned_data.csv')

# %%
df.head().T
# Out:
#                                                         0  \
# Unnamed: 0                                        2414117
# Invoice/Item Number                          S31418300050
# Date                                           2016-03-24
# Address                                      2217 COLLEGE
# City                                          CEDAR FALLS
# Zip Code                                            50613
# Store Location               POINT (-92.455796 42.517182)
# County                                         black hawk
# Category                                       1.0829e+06
# Category Name          MISC. IMPORTED CORDIALS & LIQUEURS
# Vendor Name                               Diageo Americas
# Item Number                                         66636
# Item Description           Romana Sambuca Italian Liquore
# Pack                                                   12
# Bottle Volume (ml)                                    750
# State Bottle Cost                                    13.5
# State Bottle Retail                                 20.25
# Bottles Sold                                           12
# Sale (Dollars)                                        243
# Volume Sold (Gallons)                                2.38
# Store Name                    Hillstreet News and Tobacco
# state_profit                                           81
#
#                                                     1  \
# Unnamed: 0                                    2414484
# Invoice/Item Number                      S31418300056
# Date                                       2016-03-24
# Address                                  2217 COLLEGE
# City                                      CEDAR FALLS
# Zip Code                                        50613
# Store Location           POINT (-92.455796 42.517182)
# County                                     black hawk
# Category                                  1.08139e+06
# Category Name                       IMPORTED SCHNAPPS
# Vendor Name                         Sazerac Co., Inc.
# Item Number                                     69656
# Item Description       Dr. Mcgillicuddy's Mentholmint
# Pack                                               12
# Bottle Volume (ml)                                750
# State Bottle Cost                                8.67
# State Bottle Retail                             13.01
# Bottles Sold                                       12
# Sale (Dollars)                                 156.12
# Volume Sold (Gallons)                            2.38
# Store Name                Hillstreet News and Tobacco
# state_profit                                    52.08
#
#                                                       2  \
# Unnamed: 0                                      2414605
# Invoice/Item Number                        S31418300004
# Date                                         2016-03-24
# Address                                    2217 COLLEGE
# City                                        CEDAR FALLS
# Zip Code                                          50613
# Store Location             POINT (-92.455796 42.517182)
# County                                       black hawk
# Category                                     1.0121e+06
# Category Name                         CANADIAN WHISKIES
# Vendor Name            Constellation Wine Company, Inc.
# Item Number                                       11777
# Item Description                           Black Velvet
# Pack                                                 12
# Bottle Volume (ml)                                 1000
# State Bottle Cost                                  6.63
# State Bottle Retail                                9.95
# Bottles Sold                                         48
# Sale (Dollars)                                    477.6
# Volume Sold (Gallons)                             12.68
# Store Name                  Hillstreet News and Tobacco
# state_profit                                     159.36
#
#                                                            3  \
# Unnamed: 0                                           2414652
# Invoice/Item Number                             S31298500073
# Date                                              2016-03-17
# Address                                         2217 COLLEGE
# City                                             CEDAR FALLS
# Zip Code                                               50613
# Store Location                  POINT (-92.455796 42.517182)
# County                                            black hawk
# Category                                          1.0221e+06
# Category Name                                        TEQUILA
# Vendor Name                                          Proximo
# Item Number                                            89197
# Item Description       Jose Cuervo Especial Reposado Tequila
# Pack                                                      12
# Bottle Volume (ml)                                      1000
# State Bottle Cost                                       12.5
# State Bottle Retail                                    18.75
# Bottles Sold                                              24
# Sale (Dollars)                                           450
# Volume Sold (Gallons)                                   6.34
# Store Name                       Hillstreet News and Tobacco
# state_profit                                             150
#
#                                                   4
# Unnamed: 0                                  2415000
# Invoice/Item Number                    S31418300032
# Date                                     2016-03-24
# Address                                2217 COLLEGE
# City                                    CEDAR FALLS
# Zip Code                                      50613
# Store Location         POINT (-92.455796 42.517182)
# County                                   black hawk
# Category                                1.03108e+06
# Category Name                        VODKA 80 PROOF
# Vendor Name                   Sazerac North America
# Item Number                                   37937
# Item Description                         Skol Vodka
# Pack                                             12
# Bottle Volume (ml)                             1000
# State Bottle Cost                              4.42
# State Bottle Retail                            6.63
# Bottles Sold                                     12
# Sale (Dollars)                                79.56
# Volume Sold (Gallons)                          3.17
# Store Name              Hillstreet News and Tobacco
# state_profit                                  26.52

# %% [markdown]
# We will drop the features that are not necessary for our EDA.

# %%
df = df.drop(['Unnamed: 0','Invoice/Item Number','Address','Category','Item Number'], axis = 1)
df.head().T
# Out:
#                                                         0  \
# Date                                           2016-03-24
# City                                          CEDAR FALLS
# Zip Code                                            50613
# Store Location               POINT (-92.455796 42.517182)
# County                                         black hawk
# Category Name          MISC. IMPORTED CORDIALS & LIQUEURS
# Vendor Name                               Diageo Americas
# Item Description           Romana Sambuca Italian Liquore
# Pack                                                   12
# Bottle Volume (ml)                                    750
# State Bottle Cost                                    13.5
# State Bottle Retail                                 20.25
# Bottles Sold                                           12
# Sale (Dollars)                                        243
# Volume Sold (Gallons)                                2.38
# Store Name                    Hillstreet News and Tobacco
# state_profit                                           81
#
#                                                     1  \
# Date                                       2016-03-24
# City                                      CEDAR FALLS
# Zip Code                                        50613
# Store Location           POINT (-92.455796 42.517182)
# County                                     black hawk
# Category Name                       IMPORTED SCHNAPPS
# Vendor Name                         Sazerac Co., Inc.
# Item Description       Dr. Mcgillicuddy's Mentholmint
# Pack                                               12
# Bottle Volume (ml)                                750
# State Bottle Cost                                8.67
# State Bottle Retail                             13.01
# Bottles Sold                                       12
# Sale (Dollars)                                 156.12
# Volume Sold (Gallons)                            2.38
# Store Name                Hillstreet News and Tobacco
# state_profit                                    52.08
#
#                                                       2  \
# Date                                         2016-03-24
# City                                        CEDAR FALLS
# Zip Code                                          50613
# Store Location             POINT (-92.455796 42.517182)
# County                                       black hawk
# Category Name                         CANADIAN WHISKIES
# Vendor Name            Constellation Wine Company, Inc.
# Item Description                           Black Velvet
# Pack                                                 12
# Bottle Volume (ml)                                 1000
# State Bottle Cost                                  6.63
# State Bottle Retail                                9.95
# Bottles Sold                                         48
# Sale (Dollars)                                    477.6
# Volume Sold (Gallons)                             12.68
# Store Name                  Hillstreet News and Tobacco
# state_profit                                     159.36
#
#                                                            3  \
# Date                                              2016-03-17
# City                                             CEDAR FALLS
# Zip Code                                               50613
# Store Location                  POINT (-92.455796 42.517182)
# County                                            black hawk
# Category Name                                        TEQUILA
# Vendor Name                                          Proximo
# Item Description       Jose Cuervo Especial Reposado Tequila
# Pack                                                      12
# Bottle Volume (ml)                                      1000
# State Bottle Cost                                       12.5
# State Bottle Retail                                    18.75
# Bottles Sold                                              24
# Sale (Dollars)                                           450
# Volume Sold (Gallons)                                   6.34
# Store Name                       Hillstreet News and Tobacco
# state_profit                                             150
#
#                                                   4
# Date                                     2016-03-24
# City                                    CEDAR FALLS
# Zip Code                                      50613
# Store Location         POINT (-92.455796 42.517182)
# County                                   black hawk
# Category Name                        VODKA 80 PROOF
# Vendor Name                   Sazerac North America
# Item Description                         Skol Vodka
# Pack                                             12
# Bottle Volume (ml)                             1000
# State Bottle Cost                              4.42
# State Bottle Retail                            6.63
# Bottles Sold                                     12
# Sale (Dollars)                                79.56
# Volume Sold (Gallons)                          3.17
# Store Name              Hillstreet News and Tobacco
# state_profit                                  26.52

# %% [markdown]
# Lastly, during our preliminary EDA we discovered that some cities are in lower case, while other in upper case. To avoind having the same issue with the remaining data we will transform every object feature from our dataFrame into lowercase.

# %%
for columns in ['City', 'Store Location', 'County', 'Category Name', 'Vendor Name', 'Item Description', 'Store Name']:
    df[columns] = df[columns].str.lower()

# %%
# Inspect categorical columns
df.describe(exclude=[np.number], datetime_is_numeric=True).T
# Out:
#                      count unique                                   top  \
# Date              21641145    NaN                                   NaN
# City              21641145    459                            des moines
# Store Location    21641145   2067  point (-91.53046300000001 41.642764)
# County            21641145     99                                  polk
# Category Name     21641145    112                     canadian whiskies
# Vendor Name       21641145    491                       diageo americas
# Item Description  21641145   9353                          black velvet
# Store Name        21641145   2495          hy-vee #3 / bdi / des moines
#
#                      freq                          mean        min        25%  \
# Date                  NaN 2016-12-19 17:45:35.215772160 2012-01-03 2014-08-14
# City              1873606                           NaT        NaT        NaT
# Store Location     195881                           NaT        NaT        NaT
# County            3976377                           NaT        NaT        NaT
# Category Name     2090073                           NaT        NaT        NaT
# Vendor Name       3631610                           NaT        NaT        NaT
# Item Description   556925                           NaT        NaT        NaT
# Store Name         181797                           NaT        NaT        NaT
#
#                         50%        75%        max
# Date             2017-01-20 2019-05-22 2021-06-30
# City                    NaT        NaT        NaT
# Store Location          NaT        NaT        NaT
# County                  NaT        NaT        NaT
# Category Name           NaT        NaT        NaT
# Vendor Name             NaT        NaT        NaT
# Item Description        NaT        NaT        NaT
# Store Name              NaT        NaT        NaT

# %%
# Inspect numerical columns
df.describe(include=[np.number]).T
# Out:
#                             count          mean         std       min  \
# Zip Code               21641145.0  51265.021904  989.089753  50002.00
# Pack                   21641145.0     12.256196    7.693593      1.00
# Bottle Volume (ml)     21641145.0    904.075270  653.411025      0.00
# State Bottle Cost      21641145.0     10.042841   10.735992      0.00
# State Bottle Retail    21641145.0     15.077664   16.103339      0.00
# Bottles Sold           21641145.0     10.442350   28.283905      0.00
# Sale (Dollars)         21641145.0    136.985590  470.601327      0.00
# Volume Sold (Gallons)  21641145.0      2.413350    8.962290      0.00
# state_profit           21641145.0     45.778322  157.291485  -2901.96
#
#                             25%       50%       75%        max
# Zip Code               50316.00  51101.00  52303.00   57222.00
# Pack                       6.00     12.00     12.00     336.00
# Bottle Volume (ml)       750.00    750.00   1000.00  378000.00
# State Bottle Cost          5.50      8.25     12.34    7680.00
# State Bottle Retail        8.25     12.38     18.60   11520.00
# Bottles Sold               3.00      6.00     12.00   15000.00
# Sale (Dollars)            32.28     72.00    141.72  279557.28
# Volume Sold (Gallons)      0.40      1.27      2.77    3962.58
# state_profit              10.80     24.00     47.45   93225.60

# %%
df[['Date']] = df[['Date']].apply(pd.to_datetime)
df.dtypes
# Out:
# Date                     datetime64[ns]
# City                             object
# Zip Code                          int64
# Store Location                   object
# County                           object
# Category Name                    object
# Vendor Name                      object
# Item Description                 object
# Pack                            float64
# Bottle Volume (ml)              float64
# State Bottle Cost               float64
# State Bottle Retail             float64
# Bottles Sold                    float64
# Sale (Dollars)                  float64
# Volume Sold (Gallons)           float64
# Store Name                       object
# state_profit                    float64
# dtype: object

# %% [markdown]
# #### City

# %%
subset = df.groupby('City').agg({'state_profit':'sum', 'Volume Sold (Gallons)':'sum'})
subset
# Out:
#           state_profit  Volume Sold (Gallons)
# City
# ackley       212617.23               14312.90
# adair        166419.36                8352.21
# adel        1361564.75               77186.69
# afton        119259.25                7088.46
# akron        123841.61                7621.23
# ...                ...                    ...
# winthrop     228985.34               13106.88
# woodbine     253378.64               15280.97
# woodward     102781.09                5704.17
# wyoming        8737.79                 375.54
# zwingle       87081.05                4804.93
#
# [459 rows x 2 columns]

# %% [markdown]
# We can see that there are the same cities in different formats

# %%
sns.jointplot(data = subset, x = 'Volume Sold (Gallons)', y = 'state_profit', kind = 'reg')

# %% [markdown]
# As expected, the volume sold is dirrectly correlated with the state profit. but we can see that while most cities are averaging up to 10,000,000 Gallons, there are a few that are buying up to 70M Gallons.

# %% [markdown]
# Let's explore the biggest buyers

# %%
top_20 = subset.sort_values('Volume Sold (Gallons)', ascending = False).head(20).round()
top_20
# Out:
#                  state_profit  Volume Sold (Gallons)
# City
# des moines        121044719.0              5688560.0
# cedar rapids       66682806.0              3491570.0
# davenport          50736455.0              2575573.0
# west des moines    38202360.0              1832668.0
# waterloo           34991989.0              1744894.0
# council bluffs     33149700.0              1697181.0
# sioux city         32741190.0              1674534.0
# iowa city          33094419.0              1667914.0
# ames               26869123.0              1429015.0
# dubuque            26988787.0              1428352.0
# ankeny             21525216.0              1103443.0
# cedar falls        18501082.0               974970.0
# coralville         20396266.0               957273.0
# windsor heights    16346348.0               871889.0
# bettendorf         17586818.0               843943.0
# mason city         14555320.0               828950.0
# fort dodge         11810325.0               661673.0
# clinton             9780726.0               550425.0
# muscatine           9973746.0               542604.0
# urbandale          11864982.0               535876.0

# %%
top_20 = top_20.reset_index()

# %%
plt.bar(height = top_20['Volume Sold (Gallons)'], x = top_20.City)
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ### County

# %% [markdown]
# We will import some new data for this EDA, more precisely the **annual personal income per county** from [Iowa.Gov](https://data.iowa.gov/Economic-Statistics/Annual-Personal-Income-for-State-of-Iowa-by-County/st2k-2ti2/data).

# %%
income = pd.read_csv('../data/raw/Annual_Personal_Income_for_State_of_Iowa_by_County.csv')
income.head()
# Out:
#                        Row ID  Geography ID           Name Variable Code  \
# 0  19001_2019_CAINC1-3_annual         19001      Adair, IA      CAINC1-3
# 1  19003_2019_CAINC1-3_annual         19003      Adams, IA      CAINC1-3
# 2  19005_2019_CAINC1-3_annual         19005  Allamakee, IA      CAINC1-3
# 3  19007_2019_CAINC1-3_annual         19007  Appanoose, IA      CAINC1-3
# 4  19009_2019_CAINC1-3_annual         19009    Audubon, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  55251       Dollars  12/31/2019
# 1  Per capita personal income  66683       Dollars  12/31/2019
# 2  Per capita personal income  49945       Dollars  12/31/2019
# 3  Per capita personal income  40000       Dollars  12/31/2019
# 4  Per capita personal income  58359       Dollars  12/31/2019
#
#                        Location
# 0  POINT (-94.478164 41.328528)
# 1  POINT (-94.696906 41.021656)
# 2  POINT (-91.382751 43.274964)
# 3  POINT (-92.873061 40.744296)
# 4  POINT (-94.904312 41.679178)

# %%
income['County'] = income['Name'].str[:-4]
income['County'] = income['County'].str.lower()
income.head()
# Out:
#                        Row ID  Geography ID           Name Variable Code  \
# 0  19001_2019_CAINC1-3_annual         19001      Adair, IA      CAINC1-3
# 1  19003_2019_CAINC1-3_annual         19003      Adams, IA      CAINC1-3
# 2  19005_2019_CAINC1-3_annual         19005  Allamakee, IA      CAINC1-3
# 3  19007_2019_CAINC1-3_annual         19007  Appanoose, IA      CAINC1-3
# 4  19009_2019_CAINC1-3_annual         19009    Audubon, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  55251       Dollars  12/31/2019
# 1  Per capita personal income  66683       Dollars  12/31/2019
# 2  Per capita personal income  49945       Dollars  12/31/2019
# 3  Per capita personal income  40000       Dollars  12/31/2019
# 4  Per capita personal income  58359       Dollars  12/31/2019
#
#                        Location     County
# 0  POINT (-94.478164 41.328528)      adair
# 1  POINT (-94.696906 41.021656)      adams
# 2  POINT (-91.382751 43.274964)  allamakee
# 3  POINT (-92.873061 40.744296)  appanoose
# 4  POINT (-94.904312 41.679178)    audubon

# %%
income = income[['County', 'Value']]
income
# Out:
#         County  Value
# 0        adair  55251
# 1        adams  66683
# 2    allamakee  49945
# 3    appanoose  40000
# 4      audubon  58359
# ..         ...    ...
# 94   winnebago  45793
# 95  winneshiek  51904
# 96    woodbury  45132
# 97       worth  44675
# 98      wright  55258
#
# [99 rows x 2 columns]

# %%
income.dtypes
# Out:
# County    object
# Value      int64
# dtype: object

# %% [markdown]
# Now let's see if the volume bouth per county is correlated with the income per capita.

# %%
subset = df.groupby('County').agg({'Volume Sold (Gallons)':'sum', 'State Bottle Retail':'mean'}).round(1)
subset
# Out:
#             Volume Sold (Gallons)  State Bottle Retail
# County
# adair                     82543.2                 13.8
# adams                     19204.2                 15.8
# allamakee                173774.1                 15.1
# appanoose                160313.3                 14.9
# audubon                   37928.6                 13.6
# ...                           ...                  ...
# winnebago                155597.9                 15.1
# winneshiek               256839.4                 16.1
# woodbury                1751674.2                 15.1
# worth                     54635.1                 14.5
# wright                   150642.0                 14.5
#
# [99 rows x 2 columns]

# %%
subset = subset.reset_index()

subset = subset.merge(income, on = 'County')
subset
# Out:
#         County  Volume Sold (Gallons)  State Bottle Retail  Value
# 0        adair                82543.2                 13.8  55251
# 1        adams                19204.2                 15.8  66683
# 2    allamakee               173774.1                 15.1  49945
# 3    appanoose               160313.3                 14.9  40000
# 4      audubon                37928.6                 13.6  58359
# ..         ...                    ...                  ...    ...
# 94   winnebago               155597.9                 15.1  45793
# 95  winneshiek               256839.4                 16.1  51904
# 96    woodbury              1751674.2                 15.1  45132
# 97       worth                54635.1                 14.5  44675
# 98      wright               150642.0                 14.5  55258
#
# [99 rows x 4 columns]

# %%
subset.columns = ['County','Volume', 'Avg_price_per_bottle', 'Avg_income']

# %%
sns.jointplot(data = subset, y = 'Volume', x = 'Avg_income', kind = 'reg')

# %% [markdown]
# We can see that there are no correlation between how rich are the residents of a county and how much Volume of Spirits was sold in that county.

# %%
sns.jointplot(data = subset, y = 'Avg_price_per_bottle', x = 'Avg_income', kind = 'reg')

# %% [markdown]
# We can see that there is a slight correlation between how wealthy are the residents of a county and the average bottle cost sold in that county.

# %% [markdown]
# ## 1.  The impact of Covid-19 on the Alcoholic Beverages Industry

# %%
df = pd.read_csv('../data/interim/pandemicEDA_df.csv')

# %%
df
# Out:
#           Unnamed: 0        Date                       Store Name  \
# 0            2414117  2016-03-24      Hillstreet News and Tobacco
# 1            2414484  2016-03-24      Hillstreet News and Tobacco
# 2            2414605  2016-03-24      Hillstreet News and Tobacco
# 3            2414652  2016-03-17      Hillstreet News and Tobacco
# 4            2415000  2016-03-24      Hillstreet News and Tobacco
# ...              ...         ...                              ...
# 21641140     4647896  2017-11-17         Cats Eye Distillery, LLC
# 21641141     4622234  2018-05-23       Green Frog Distillery, LLC
# 21641142     4610127  2018-07-26         Templeton Distilling LLC
# 21641143     2275966  2020-10-15  Rock River Distillation Company
# 21641144     2280453  2020-10-15  Rock River Distillation Company
#
#                  City      County  \
# 0         CEDAR FALLS  black hawk
# 1         CEDAR FALLS  black hawk
# 2         CEDAR FALLS  black hawk
# 3         CEDAR FALLS  black hawk
# 4         CEDAR FALLS  black hawk
# ...               ...         ...
# 21641140   Bettendorf       scott
# 21641141       Keokuk         lee
# 21641142    Templeton     carroll
# 21641143  Rock Rapids        lyon
# 21641144  Rock Rapids        lyon
#
#                                               Vendor Name  \
# 0                                         Diageo Americas
# 1                                       Sazerac Co., Inc.
# 2                        Constellation Wine Company, Inc.
# 3                                                 Proximo
# 4                                   Sazerac North America
# ...                                                   ...
# 21641140                              Cats Eye Distillery
# 21641141                       Green Frog Distillery, LLC
# 21641142                         Templeton Distilling LLC
# 21641143  Rocky Top Investments / Rock River Distillation
# 21641144  Rocky Top Investments / Rock River Distillation
#
#                                Category Name  \
# 0         MISC. IMPORTED CORDIALS & LIQUEURS
# 1                          IMPORTED SCHNAPPS
# 2                          CANADIAN WHISKIES
# 3                                    TEQUILA
# 4                             VODKA 80 PROOF
# ...                                      ...
# 21641140                       Corn Whiskies
# 21641141                       Corn Whiskies
# 21641142                    Blended Whiskies
# 21641143      Temporary & Specialty Packages
# 21641144     Temporary &  Specialty Packages
#
#                                      Item Description  Sale (Dollars)  \
# 0                      Romana Sambuca Italian Liquore          243.00
# 1                      Dr. Mcgillicuddy's Mentholmint          156.12
# 2                                        Black Velvet          477.60
# 3               Jose Cuervo Especial Reposado Tequila          450.00
# 4                                          Skol Vodka           79.56
# ...                                               ...             ...
# 21641140                      Essence of Iowa Whiskey          346.56
# 21641141  Green Frog Distillery Straight Corn Whiskey          157.50
# 21641142            Templeton Rye Special Reserve 8YR          246.72
# 21641143                                 Revenant Rye         1620.00
# 21641144                        Double Barrel Bourbon         2700.00
#
#           Volume Sold (Gallons)  state_profit
# 0                          2.38         81.00
# 1                          2.38         52.08
# 2                         12.68        159.36
# 3                          6.34        150.00
# 4                          3.17         26.52
# ...                         ...           ...
# 21641140                   0.19          9.63
# 21641141                   0.39         17.50
# 21641142                   9.70        671.79
# 21641143                   7.13        540.00
# 21641144                  11.88        900.00
#
# [21641145 rows x 11 columns]

# %% [markdown]
# We will drop the first unnecesary column that originates from the former index.

# %%
df = df.iloc[: , 1:]

# %%
# Inspect categorical columns
df.describe(exclude=[np.number]).T
# Out:
#                      count unique                           top     freq
# Date              21641145   2345                    2020-12-22    18002
# Store Name        21641145   2506  Hy-Vee #3 / BDI / Des Moines   181797
# City              21641145    842                    Des Moines  1062521
# County            21641145     99                          polk  3976377
# Vendor Name       21641145    528               Jim Beam Brands  2036406
# Category Name     21641145    135               American Vodkas  1747627
# Item Description  21641145   9497                  Black Velvet   556925

# %%
# Inspect numerical columns
df.describe(include=[np.number]).T
# Out:
#                             count        mean         std      min    25%  \
# Sale (Dollars)         21641145.0  136.985590  470.601327     0.00  32.28
# Volume Sold (Gallons)  21641145.0    2.413350    8.962290     0.00   0.40
# state_profit           21641145.0   45.778322  157.291485 -2901.96  10.80
#
#                          50%     75%        max
# Sale (Dollars)         72.00  141.72  279557.28
# Volume Sold (Gallons)   1.27    2.77    3962.58
# state_profit           24.00   47.45   93225.60
