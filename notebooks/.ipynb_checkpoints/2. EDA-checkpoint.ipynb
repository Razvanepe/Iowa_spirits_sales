# %% [markdown]
# # Predicting Liquor Sales Profit and post-Pandemic Business Analytics

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Identified Business Problems

# %% [markdown]
# As presented in the previous notebook and in the Project proposal, we are using a large dataset to help stakeholders make data-driven business decisions. We identified a few avenues for explorations.
#
# In this EDA notebook, apart from our general Exploratory FEature Analysis(univariate, bivariate, multivariate) we will also answer 2 Business Problems:
#
# 1. We will conduct Exploratory Data Analysis on what was **the impact of Covid-19 on the Alcoholic Beverages Industry**. We will take into consideration the demographic trends and Income per capita, but we will also make our recommendations and analysis considering the “regression to the mean” statistical principle.
#
# 2. We will also conduct **Storage Capacity** exploratory analysis with the purpose of predicting how the storage needs will change within one year from the current date.
#
# Later, in our next Notebook we will approach another Business problems that concerns the Alcoholic Beverages Division of Iowa:
#
# 3. Cohort Analysis and **Customer Segmentation using RFM(Recency, Frequency and Monetary value) and Unsupervised Learning** in oru Pre-Processing section.
#
# Finally, in our Modeling Part, we will focus on driving Business Insight to help a hypothetical liquor store owner make strategic decisions:
#
# 4. We want to assist him in **expanding to new locations** throughout the state.
# 5. Lastly, we want to use existing data for a **time series analysis and predictions to forecast sales for next month**.

# %% [markdown]
# ### EDA setup

# %% [markdown]
# In the Data Wrangling part of this project we used our initial data and because of the large size we divided our initial data in several subset. Each of them to be used for specific Business problems. These are the datasets created:
# * pandemicEDA
# * storageEDA
# * cust_segmentation
# * pick_new_location
# * predict_sales
# * df - this is the original data, cleaned of missing data, ouliers and checked for consistency

# %% [markdown]
# We have this plan to conduct EDA:
#
#    1. Conduct univariate EDA on our data
#    2. Conduct bivariate EDA on variables with our target feature
#    3. Multivariate EDA
#    4. conduct Analysis of how Covid-19 impacted the Spirits Industry in Iowa
#    5. conduct Analysis on volume of alcoholic beverages sold within difeerent time periods: weekly, monthly and on a three months period to identify storage needs and trends.

# %% [markdown]
# ![1586552655_Step_3_colorful_group.png](attachment:1586552655_Step_3_colorful_group.png)

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)
import seaborn as sns
sns.set_theme(style="whitegrid")

import pandas.plotting
from IPython import display
from ipywidgets import interact, widgets

# %% [markdown]
# ## 1. Features Analysis

# %%
df = pd.read_csv('../data/interim/cleaned_data.csv', parse_dates = True, low_memory=False, usecols = ['Date', 'City',
                'Zip Code', 'Store Location', 'County', 'Category Name', 'Vendor Name', 'Item Description', 'Pack',
                'Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold', 'Sale (Dollars)',
                'Volume Sold (Gallons)', 'Store Name','state_profit'])

# %%
df.head().T
# Out:
#                                                         0  \
# Date                                           2016-03-24
# City                                          CEDAR FALLS
# Zip Code                                            50613
# Store Location               POINT (-92.455796 42.517182)
# County                                         black hawk
# Category Name          MISC. IMPORTED CORDIALS & LIQUEURS
# Vendor Name                               Diageo Americas
# Item Description           Romana Sambuca Italian Liquore
# Pack                                                   12
# Bottle Volume (ml)                                    750
# State Bottle Cost                                    13.5
# State Bottle Retail                                 20.25
# Bottles Sold                                           12
# Sale (Dollars)                                        243
# Volume Sold (Gallons)                                2.38
# Store Name                    Hillstreet News and Tobacco
# state_profit                                           81
#
#                                                     1  \
# Date                                       2016-03-24
# City                                      CEDAR FALLS
# Zip Code                                        50613
# Store Location           POINT (-92.455796 42.517182)
# County                                     black hawk
# Category Name                       IMPORTED SCHNAPPS
# Vendor Name                         Sazerac Co., Inc.
# Item Description       Dr. Mcgillicuddy's Mentholmint
# Pack                                               12
# Bottle Volume (ml)                                750
# State Bottle Cost                                8.67
# State Bottle Retail                             13.01
# Bottles Sold                                       12
# Sale (Dollars)                                 156.12
# Volume Sold (Gallons)                            2.38
# Store Name                Hillstreet News and Tobacco
# state_profit                                    52.08
#
#                                                       2  \
# Date                                         2016-03-24
# City                                        CEDAR FALLS
# Zip Code                                          50613
# Store Location             POINT (-92.455796 42.517182)
# County                                       black hawk
# Category Name                         CANADIAN WHISKIES
# Vendor Name            Constellation Wine Company, Inc.
# Item Description                           Black Velvet
# Pack                                                 12
# Bottle Volume (ml)                                 1000
# State Bottle Cost                                  6.63
# State Bottle Retail                                9.95
# Bottles Sold                                         48
# Sale (Dollars)                                    477.6
# Volume Sold (Gallons)                             12.68
# Store Name                  Hillstreet News and Tobacco
# state_profit                                     159.36
#
#                                                            3  \
# Date                                              2016-03-17
# City                                             CEDAR FALLS
# Zip Code                                               50613
# Store Location                  POINT (-92.455796 42.517182)
# County                                            black hawk
# Category Name                                        TEQUILA
# Vendor Name                                          Proximo
# Item Description       Jose Cuervo Especial Reposado Tequila
# Pack                                                      12
# Bottle Volume (ml)                                      1000
# State Bottle Cost                                       12.5
# State Bottle Retail                                    18.75
# Bottles Sold                                              24
# Sale (Dollars)                                           450
# Volume Sold (Gallons)                                   6.34
# Store Name                       Hillstreet News and Tobacco
# state_profit                                             150
#
#                                                   4
# Date                                     2016-03-24
# City                                    CEDAR FALLS
# Zip Code                                      50613
# Store Location         POINT (-92.455796 42.517182)
# County                                   black hawk
# Category Name                        VODKA 80 PROOF
# Vendor Name                   Sazerac North America
# Item Description                         Skol Vodka
# Pack                                             12
# Bottle Volume (ml)                             1000
# State Bottle Cost                              4.42
# State Bottle Retail                            6.63
# Bottles Sold                                     12
# Sale (Dollars)                                79.56
# Volume Sold (Gallons)                          3.17
# Store Name              Hillstreet News and Tobacco
# state_profit                                  26.52

# %% [markdown]
# Lastly, during our preliminary EDA we discovered that some cities are in lower case, while other in upper case. To avoind having the same issue with the remaining data we will transform every object feature from our dataFrame into lowercase.

# %%
for columns in ['City', 'Store Location', 'County', 'Category Name', 'Vendor Name', 'Item Description', 'Store Name']:
    df[columns] = df[columns].str.lower()

# %%
# Inspect categorical columns
df.describe(exclude=[np.number], datetime_is_numeric=True).T
# Out:
#                      count unique                                   top  \
# Date              21641145   2345                            2020-12-22
# City              21641145    459                            des moines
# Store Location    21641145   2067  point (-91.53046300000001 41.642764)
# County            21641145     99                                  polk
# Category Name     21641145    112                     canadian whiskies
# Vendor Name       21641145    491                       diageo americas
# Item Description  21641145   9353                          black velvet
# Store Name        21641145   2495          hy-vee #3 / bdi / des moines
#
#                      freq
# Date                18002
# City              1873606
# Store Location     195881
# County            3976377
# Category Name     2090073
# Vendor Name       3631610
# Item Description   556925
# Store Name         181797

# %%
# Inspect numerical columns
df.describe(include=[np.number]).T
# Out:
#                             count          mean         std       min  \
# Zip Code               21641145.0  51265.021904  989.089753  50002.00
# Pack                   21641145.0     12.256196    7.693593      1.00
# Bottle Volume (ml)     21641145.0    904.075270  653.411025      0.00
# State Bottle Cost      21641145.0     10.042841   10.735992      0.00
# State Bottle Retail    21641145.0     15.077664   16.103339      0.00
# Bottles Sold           21641145.0     10.442350   28.283905      0.00
# Sale (Dollars)         21641145.0    136.985590  470.601327      0.00
# Volume Sold (Gallons)  21641145.0      2.413350    8.962290      0.00
# state_profit           21641145.0     45.778322  157.291485  -2901.96
#
#                             25%       50%       75%        max
# Zip Code               50316.00  51101.00  52303.00   57222.00
# Pack                       6.00     12.00     12.00     336.00
# Bottle Volume (ml)       750.00    750.00   1000.00  378000.00
# State Bottle Cost          5.50      8.25     12.34    7680.00
# State Bottle Retail        8.25     12.38     18.60   11520.00
# Bottles Sold               3.00      6.00     12.00   15000.00
# Sale (Dollars)            32.28     72.00    141.72  279557.28
# Volume Sold (Gallons)      0.40      1.27      2.77    3962.58
# state_profit              10.80     24.00     47.45   93225.60

# %%
df[['Date']] = df[['Date']].apply(pd.to_datetime)
df.dtypes
# Out:
# Date                     datetime64[ns]
# City                             object
# Zip Code                          int64
# Store Location                   object
# County                           object
# Category Name                    object
# Vendor Name                      object
# Item Description                 object
# Pack                            float64
# Bottle Volume (ml)              float64
# State Bottle Cost               float64
# State Bottle Retail             float64
# Bottles Sold                    float64
# Sale (Dollars)                  float64
# Volume Sold (Gallons)           float64
# Store Name                       object
# state_profit                    float64
# dtype: object

# %% [markdown]
# #### City

# %%
city_subset = df.groupby('City').agg({'state_profit':'sum', 'Volume Sold (Gallons)':'sum'})
city_subset
# Out:
#           state_profit  Volume Sold (Gallons)
# City
# ackley       212617.23               14312.90
# adair        166419.36                8352.21
# adel        1361564.75               77186.69
# afton        119259.25                7088.46
# akron        123841.61                7621.23
# ...                ...                    ...
# winthrop     228985.34               13106.88
# woodbine     253378.64               15280.97
# woodward     102781.09                5704.17
# wyoming        8737.79                 375.54
# zwingle       87081.05                4804.93
#
# [459 rows x 2 columns]

# %% [markdown]
# We can see that there are the same cities in different formats

# %%
sns.jointplot(data = city_subset, x = 'Volume Sold (Gallons)', y = 'state_profit', kind = 'reg')

# %% [markdown]
# As expected, the volume sold is dirrectly correlated with the state profit. but we can see that while most cities are averaging up to 1,000,000 Gallons, there are a few that are buying up to 5.5M Gallons.

# %% [markdown]
# Let's explore the biggest buyers

# %%
top_20_cities = city_subset.sort_values('Volume Sold (Gallons)', ascending = False).head(20).round()
top_20_cities
# Out:
#                  state_profit  Volume Sold (Gallons)
# City
# des moines        121044719.0              5688560.0
# cedar rapids       66682806.0              3491570.0
# davenport          50736455.0              2575573.0
# west des moines    38202360.0              1832668.0
# waterloo           34991989.0              1744894.0
# council bluffs     33149700.0              1697181.0
# sioux city         32741190.0              1674534.0
# iowa city          33094419.0              1667914.0
# ames               26869123.0              1429015.0
# dubuque            26988787.0              1428352.0
# ankeny             21525216.0              1103443.0
# cedar falls        18501082.0               974970.0
# coralville         20396266.0               957273.0
# windsor heights    16346348.0               871889.0
# bettendorf         17586818.0               843943.0
# mason city         14555320.0               828950.0
# fort dodge         11810325.0               661673.0
# clinton             9780726.0               550425.0
# muscatine           9973746.0               542604.0
# urbandale          11864982.0               535876.0

# %%
top_20_cities = top_20_cities.reset_index()

# %%
plt.bar(height = top_20_cities['Volume Sold (Gallons)'], x = top_20_cities.City)
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ### County

# %% [markdown]
# We will import some new data for this EDA, more precisely the **annual personal income per county** from [Iowa.Gov](https://data.iowa.gov/Economic-Statistics/Annual-Personal-Income-for-State-of-Iowa-by-County/st2k-2ti2/data).

# %%
income = pd.read_csv('../data/raw/Annual_Personal_Income_for_State_of_Iowa_by_County.csv')
income.head()
# Out:
#                        Row ID  Geography ID           Name Variable Code  \
# 0  19001_2019_CAINC1-3_annual         19001      Adair, IA      CAINC1-3
# 1  19003_2019_CAINC1-3_annual         19003      Adams, IA      CAINC1-3
# 2  19005_2019_CAINC1-3_annual         19005  Allamakee, IA      CAINC1-3
# 3  19007_2019_CAINC1-3_annual         19007  Appanoose, IA      CAINC1-3
# 4  19009_2019_CAINC1-3_annual         19009    Audubon, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  55251       Dollars  12/31/2019
# 1  Per capita personal income  66683       Dollars  12/31/2019
# 2  Per capita personal income  49945       Dollars  12/31/2019
# 3  Per capita personal income  40000       Dollars  12/31/2019
# 4  Per capita personal income  58359       Dollars  12/31/2019
#
#                        Location
# 0  POINT (-94.478164 41.328528)
# 1  POINT (-94.696906 41.021656)
# 2  POINT (-91.382751 43.274964)
# 3  POINT (-92.873061 40.744296)
# 4  POINT (-94.904312 41.679178)

# %%
income['County'] = income['Name'].str[:-4]
income['County'] = income['County'].str.lower()
income.head()
# Out:
#                        Row ID  Geography ID           Name Variable Code  \
# 0  19001_2019_CAINC1-3_annual         19001      Adair, IA      CAINC1-3
# 1  19003_2019_CAINC1-3_annual         19003      Adams, IA      CAINC1-3
# 2  19005_2019_CAINC1-3_annual         19005  Allamakee, IA      CAINC1-3
# 3  19007_2019_CAINC1-3_annual         19007  Appanoose, IA      CAINC1-3
# 4  19009_2019_CAINC1-3_annual         19009    Audubon, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  55251       Dollars  12/31/2019
# 1  Per capita personal income  66683       Dollars  12/31/2019
# 2  Per capita personal income  49945       Dollars  12/31/2019
# 3  Per capita personal income  40000       Dollars  12/31/2019
# 4  Per capita personal income  58359       Dollars  12/31/2019
#
#                        Location     County
# 0  POINT (-94.478164 41.328528)      adair
# 1  POINT (-94.696906 41.021656)      adams
# 2  POINT (-91.382751 43.274964)  allamakee
# 3  POINT (-92.873061 40.744296)  appanoose
# 4  POINT (-94.904312 41.679178)    audubon

# %%
income = income[['County', 'Value']]
income
# Out:
#         County  Value
# 0        adair  55251
# 1        adams  66683
# 2    allamakee  49945
# 3    appanoose  40000
# 4      audubon  58359
# ..         ...    ...
# 94   winnebago  45793
# 95  winneshiek  51904
# 96    woodbury  45132
# 97       worth  44675
# 98      wright  55258
#
# [99 rows x 2 columns]

# %%
income.dtypes
# Out:
# County    object
# Value      int64
# dtype: object

# %% [markdown]
# Now let's see if the volume bouth per county is correlated with the income per capita.

# %%
subset_county = df.groupby('County').agg({'Volume Sold (Gallons)':'sum', 'State Bottle Retail':'mean'}).round(1)
subset_county
# Out:
#             Volume Sold (Gallons)  State Bottle Retail
# County
# adair                     82543.2                 13.8
# adams                     19204.2                 15.8
# allamakee                173774.1                 15.1
# appanoose                160313.3                 14.9
# audubon                   37928.6                 13.6
# ...                           ...                  ...
# winnebago                155597.9                 15.1
# winneshiek               256839.4                 16.1
# woodbury                1751674.2                 15.1
# worth                     54635.1                 14.5
# wright                   150642.0                 14.5
#
# [99 rows x 2 columns]

# %%
subset_county = subset_county.reset_index()

subset_county = subset_county.merge(income, on = 'County')
subset_county
# Out:
#         County  Volume Sold (Gallons)  State Bottle Retail  Value
# 0        adair                82543.2                 13.8  55251
# 1        adams                19204.2                 15.8  66683
# 2    allamakee               173774.1                 15.1  49945
# 3    appanoose               160313.3                 14.9  40000
# 4      audubon                37928.6                 13.6  58359
# ..         ...                    ...                  ...    ...
# 94   winnebago               155597.9                 15.1  45793
# 95  winneshiek               256839.4                 16.1  51904
# 96    woodbury              1751674.2                 15.1  45132
# 97       worth                54635.1                 14.5  44675
# 98      wright               150642.0                 14.5  55258
#
# [99 rows x 4 columns]

# %%
subset_county.columns = ['County','Volume', 'Avg_price_per_bottle', 'Avg_income']

# %%
sns.jointplot(data = subset_county, y = 'Volume', x = 'Avg_income', kind = 'reg')

# %% [markdown]
# We can see that there are no correlation between how rich are the residents of a county and how much Volume of Spirits was sold in that county.

# %%
sns.jointplot(data = subset_county, y = 'Avg_price_per_bottle', x = 'Avg_income', kind = 'reg')

# %% [markdown]
# We can see that there is a slight correlation between how wealthy are the residents of a county and the average bottle cost sold in that county.

# %% [markdown]
# ### Category

# %%
subset_cat = df.groupby('Category Name').agg({'State Bottle Retail':'mean', 'Sale (Dollars)':'sum',
                                              'state_profit': 'sum', 'Volume Sold (Gallons)':'sum'}).round(1)

# %%
subset_cat.columns = ['Avg_bottle_price', 'total_sales', 'state_profit', 'Volume']
subset_cat = subset_cat.reset_index()
subset_cat
# Out:
#              Category Name  Avg_bottle_price  total_sales  state_profit  \
# 0          100 proof vodka               8.8    7305335.8     2437842.0
# 1       100% agave tequila              28.2   65626061.3    21920287.9
# 2            aged dark rum              19.4    3479460.1     1167293.8
# 3      amaretto - imported              46.7      70470.3       23495.1
# 4         american alcohol              13.0    2966946.8      989358.0
# ..                     ...               ...          ...           ...
# 107    watermelon schnapps              10.5    1705878.7      570297.1
# 108        whiskey liqueur              17.7  146301755.0    48739328.0
# 109   white creme de cacao               6.8     241671.9       80557.1
# 110  white creme de menthe               7.0      73888.7       24625.1
# 111              white rum              11.3   31562477.5    10504173.7
#
#         Volume
# 0     253327.4
# 1     483318.4
# 2      42548.1
# 3        299.2
# 4      45374.3
# ..         ...
# 107    38918.2
# 108  2165677.6
# 109     6991.4
# 110     2097.9
# 111   783842.3
#
# [112 rows x 5 columns]

# %% [markdown]
# Let's see what are the most expensive and the msot cheap spirits categories

# %%
subset_cat = subset_cat.sort_values('Avg_bottle_price', ascending = False)

# %%
top15categ = subset_cat.head(15)
bottom15categ = subset_cat.tail(15)

# %%
subs_cat = top15categ.append(bottom15categ)
subs_cat
# Out:
#                             Category Name  Avg_bottle_price  total_sales  \
# 47             high proof beer - american             122.1       6237.8
# 64                      imported whiskies              85.4       3586.7
# 69                        japanese whisky              56.4      90508.8
# 91                     single malt scotch              47.2   31294070.1
# 3                     amaretto - imported              46.7      70470.3
# 66               iowa distillery whiskies              40.9     341602.0
# 54   imported distilled spirits specialty              35.7      37371.5
# 65                      iowa distilleries              34.2     557729.3
# 99        temporary &  specialty packages              34.1    3243973.0
# 90         single barrel bourbon whiskies              32.5    3868914.6
# 93                    special order items              29.6    8720117.1
# 71                                 mezcal              29.6     839529.4
# 96                  straight rye whiskies              28.7   30493502.9
# 1                      100% agave tequila              28.2   65626061.3
# 38         delisted / special order items              27.8        333.0
# 28                        cherry brandies               7.7     616245.0
# 97                    strawberry schnapps               7.7     543700.3
# 81                         peach brandies               7.4     767577.6
# 83                    peppermint schnapps               7.4    6163636.9
# 16                     american sloe gins               7.3     374111.8
# 104               tropical fruit schnapps               7.3     430689.1
# 92                     spearmint schnapps               7.2     136356.2
# 110                 white creme de menthe               7.0      73888.7
# 19                               anisette               6.9      37839.7
# 36                    dark creme de cacao               6.9     223658.1
# 46                  green creme de menthe               6.9     314298.4
# 109                  white creme de cacao               6.8     241671.9
# 35                        creme de almond               6.7      45315.0
# 5                       american amaretto               6.7    2847722.9
# 103                            triple sec               4.1    6946797.9
#
#      state_profit    Volume
# 47         1698.7      10.8
# 64         1195.6       8.3
# 69        30174.5     347.3
# 91     10476490.3  146850.7
# 3         23495.1     299.2
# 66       112979.8    1968.2
# 54        12353.6     195.4
# 65       185112.8    3207.9
# 99      1081412.8   31887.9
# 90      1289565.6   24846.5
# 93      2918563.9  186861.1
# 71       279878.7    5749.9
# 96     10165774.5  220667.0
# 1      21920287.9  483318.4
# 38          111.0       2.4
# 28       205460.2   15037.0
# 97       182555.2   14331.5
# 81       256163.2   17051.1
# 83      2056159.6  208648.0
# 16       124713.9   12024.2
# 104      143657.7   14329.1
# 92        45486.8    4951.2
# 110       24625.1    2097.9
# 19        12626.3    1076.7
# 36        74561.7    6488.0
# 46       104814.6    9062.2
# 109       80557.1    6991.4
# 35        15100.2    1321.3
# 5        949763.3  109461.6
# 103     2314680.8  448130.9

# %%
subs_cat = subs_cat.sort_values('Avg_bottle_price', ascending = False)
sns.barplot(data = subs_cat, y = 'Category Name', x = 'Avg_bottle_price')
# Out:
# <AxesSubplot:xlabel='Avg_bottle_price', ylabel='Category Name'>

# %% [markdown]
# We can see that the High Proof Beer - American is the most expensive one with an average of over $120 per bottle, folowed by imported Wiskey and Japanese Wiskey. The least expensive one is the Triple Sec with 4.1 per bottle.

# %%
subset_categ = subset_cat.sort_values('Volume', ascending = False)
subset_categ = subset_categ.head(30)
sns.barplot(data = subset_categ, y = 'Category Name', x = 'Volume')
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Category Name'>

# %% [markdown]
# Let's also see the most popular categories and those who are the most profitable for the state to sell.

# %%
top20popular = subset_cat.sort_values('total_sales', ascending = False).head(20)
top20popular
# Out:
#                  Category Name  Avg_bottle_price  total_sales  state_profit  \
# 27           canadian whiskies              14.7  358609126.4   120307082.2
# 18             american vodkas              10.0  246272738.3    82257844.5
# 94                  spiced rum              14.2  207114271.4    69069609.6
# 95   straight bourbon whiskies              18.4  182111000.4    60845503.6
# 108            whiskey liqueur              17.7  146301755.0    48739328.0
# 105             vodka 80 proof               9.2  145764888.8    48784116.3
# 101         tennessee whiskies              21.1  128622074.6    42878346.6
# 24            blended whiskies              11.2   85151156.9    28411840.8
# 63             imported vodkas              19.0   78573679.5    26080949.8
# 60              imported vodka              20.1   77859854.1    25996728.3
# 102                    tequila              20.1   68479198.9    22890879.2
# 34              cream liqueurs              18.4   68341414.6    22914141.8
# 1           100% agave tequila              28.2   65626061.3    21920287.9
# 43                flavored rum              12.8   62323659.2    20827277.6
# 50           imported brandies              24.2   60470298.4    20329801.2
# 67              irish whiskies              25.0   55180007.6    18502526.8
# 89             scotch whiskies              25.8   50488094.8    16828944.5
# 59           imported schnapps              16.2   49369147.3    16449526.0
# 13     american flavored vodka              10.7   46088176.7    15375543.9
# 76               mixto tequila              14.8   42788860.3    14423641.7
#
#         Volume
# 27   6843920.3
# 18   6577863.2
# 94   3560947.6
# 95   2354620.6
# 108  2165677.6
# 105  4701682.6
# 101  1194132.1
# 24   2109292.8
# 63   1130766.5
# 60    989378.0
# 102   885631.1
# 34    819166.8
# 1     483318.4
# 43   1098643.0
# 50    364728.1
# 67    492228.0
# 89    648716.8
# 59    697488.1
# 13    869259.2
# 76    708602.0

# %%
sns.barplot(data = top20popular, y = 'Category Name', x = 'total_sales')
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='Category Name'>

# %%
top20profitable = subset_cat.sort_values('state_profit', ascending = False).head(20)
top20profitable
# Out:
#                  Category Name  Avg_bottle_price  total_sales  state_profit  \
# 27           canadian whiskies              14.7  358609126.4   120307082.2
# 18             american vodkas              10.0  246272738.3    82257844.5
# 94                  spiced rum              14.2  207114271.4    69069609.6
# 95   straight bourbon whiskies              18.4  182111000.4    60845503.6
# 105             vodka 80 proof               9.2  145764888.8    48784116.3
# 108            whiskey liqueur              17.7  146301755.0    48739328.0
# 101         tennessee whiskies              21.1  128622074.6    42878346.6
# 24            blended whiskies              11.2   85151156.9    28411840.8
# 63             imported vodkas              19.0   78573679.5    26080949.8
# 60              imported vodka              20.1   77859854.1    25996728.3
# 34              cream liqueurs              18.4   68341414.6    22914141.8
# 102                    tequila              20.1   68479198.9    22890879.2
# 1           100% agave tequila              28.2   65626061.3    21920287.9
# 43                flavored rum              12.8   62323659.2    20827277.6
# 50           imported brandies              24.2   60470298.4    20329801.2
# 67              irish whiskies              25.0   55180007.6    18502526.8
# 89             scotch whiskies              25.8   50488094.8    16828944.5
# 59           imported schnapps              16.2   49369147.3    16449526.0
# 13     american flavored vodka              10.7   46088176.7    15375543.9
# 76               mixto tequila              14.8   42788860.3    14423641.7
#
#         Volume
# 27   6843920.3
# 18   6577863.2
# 94   3560947.6
# 95   2354620.6
# 105  4701682.6
# 108  2165677.6
# 101  1194132.1
# 24   2109292.8
# 63   1130766.5
# 60    989378.0
# 34    819166.8
# 102   885631.1
# 1     483318.4
# 43   1098643.0
# 50    364728.1
# 67    492228.0
# 89    648716.8
# 59    697488.1
# 13    869259.2
# 76    708602.0

# %%
sns.barplot(data = top20popular, y = 'Category Name', x = 'state_profit')
# Out:
# <AxesSubplot:xlabel='state_profit', ylabel='Category Name'>

# %%
area = subset_cat.Volume**(1/2)
color = subset_cat.total_sales

subset_cat.plot.scatter(x ='state_profit', y ='Avg_bottle_price' ,
                     c = color, colormap=matplotlib.cm.get_cmap('Spectral'),
                     s = area, edgecolors = 'k',
                     sharex=False, figsize = (15,6), alpha = 0.5)
plt.title('Scatter sales by category. Size is total volume. Color is Total Sales($)')
# plt.xscale('log')
plt.show()

# %% [markdown]
# We can see here that the main purpose of the Department is to sell as much, and with it, the more profit they will make. All the top 6 categories that are bringing the most profit are below $20 per bottle.

# %% [markdown]
# ### Item Description EDA

# %%
subset = df.groupby('Item Description').agg({'State Bottle Retail':'mean', 'Sale (Dollars)':'sum',
                                             'state_profit': 'sum', 'Volume Sold (Gallons)':'sum'}).round(1)

# %%
subset.columns = ['Avg_bottle_price', 'total_sales', 'state_profit', 'Volume']
subset = subset.reset_index()
subset
# Out:
#                              Item Description  Avg_bottle_price  total_sales  \
# 0                          "beefeater ""24"""              18.7        224.9
# 1     "jose cuervo silver ""rolling stones"""              15.8      19010.2
# 2                     "rumchata ""gochatas"""             148.5        445.5
# 3      "rumchata ""minichatas"" creamer cups"              10.5     132688.5
# 4                                   (ri)1 rye              31.5      15996.9
# ...                                       ...               ...          ...
# 9348                     zu bison grass vodka              19.3        695.5
# 9349               zubrowka bison grass vodka              19.5       6772.1
# 9350                                    zwack              22.1       3323.9
# 9351                             zwack unicum              23.9        573.1
# 9352                                zyr vodka              26.9      20666.3
#
#       state_profit  Volume
# 0             75.0     2.4
# 1           6368.2   240.6
# 2            148.5     4.7
# 3          43883.0  1242.0
# 4           5334.0   100.4
# ...            ...     ...
# 9348         231.8     7.1
# 9349        2258.5    68.9
# 9350        1108.0    29.7
# 9351         191.0     4.8
# 9352        6890.2   167.8
#
# [9353 rows x 5 columns]

# %% [markdown]
# Let's see the most expensive 20 beverages

# %%
subset = subset.sort_values('Avg_bottle_price', ascending = False)
top30 = subset.head(20)
top30
# Out:
#                                        Item Description  Avg_bottle_price  \
# 1916       cedar ridge reserve bourbon private cask dno           11520.0
# 1897               cedar ridge malted rye barrel marion            9150.0
# 1904          cedar ridge port cask finish barrel #2666            9000.0
# 1902          cedar ridge port cask finish barrel #2590            9000.0
# 1903          cedar ridge port cask finish barrel #2663            9000.0
# 1901          cedar ridge port cask finish barrel #2561            9000.0
# 1880            cedar ridge barrel proof bourbon barrel            8700.0
# 1881      cedar ridge barrel proof bourbon barrel #2552            8700.0
# 1879  cedar ridge barrel proof bourbon - use code 92...            8700.0
# 1882      cedar ridge barrel proof bourbon barrel #2666            8700.0
# 1877            cedar ridge barrel aged rum 5yr reserve            8250.0
# 23       18 cases smirnoff 1.75l/18 cases captain 1.75l            5305.9
# 1917           cedar ridge rye whiskey - whole cask buy            4870.4
# 1898            cedar ridge malted rye barrel urbandale            4594.1
# 4140                                 ha port ellen 37yr            3375.0
# 2417                  crown royal multi branded shipper            2806.8
# 4303                          hennessy paradis imperial            2594.2
# 7092                             remy martin louis xiii            2551.9
# 291                absolut w/ zing zang bloody mary mix            2398.8
# 4304                    hennessy paradis imperial 750ml            2362.5
#
#       total_sales  state_profit  Volume
# 1916      11520.0        3840.0     0.2
# 1897       9150.0        3050.0    47.6
# 1904       9000.0        3000.0     0.2
# 1902       9000.0        3000.0     0.2
# 1903       9000.0        3000.0     0.2
# 1901       9000.0        3000.0     0.2
# 1880       8700.0        2900.0     0.2
# 1881       8700.0        2900.0     0.2
# 1879      17400.0        5800.0     0.4
# 1882       8700.0        2900.0     0.2
# 1877       8250.0        2750.0    59.4
# 23       127342.8       42447.6  2396.6
# 1917      38692.2       13832.4   212.8
# 1898      18300.0        3062.7    47.8
# 4140       3375.0        1125.0     0.2
# 2417      39295.2       13098.4     2.8
# 4303       2594.2         864.7     0.2
# 7092      79310.4       26337.3     5.3
# 291       23988.0        7996.0   369.8
# 4304       2362.5         787.5     0.2

# %% [markdown]
# And the most popular 20 beverages

# %%
subset = subset.sort_values('Volume', ascending = False)
top30 = subset.head(20)
top30
# Out:
#                     Item Description  Avg_bottle_price  total_sales  \
# 1106                    black velvet              10.1  116882147.8
# 4262                   hawkeye vodka               7.2   52684111.7
# 8729            titos handmade vodka              18.6   87854437.8
# 1780       captain morgan spiced rum              17.4   73458084.9
# 3374              five o'clock vodka               7.2   27902985.3
# 3326       fireball cinnamon whiskey              13.6   65500491.9
# 887                     barton vodka               7.8   21654138.3
# 6742                  phillips vodka               9.2   16926297.1
# 4673   jack daniels old #7 black lbl              26.0   67262714.6
# 331        admiral nelson spiced rum              12.1   23683369.4
# 1747  captain morgan original spiced              14.4   36354766.6
# 4840                        jim beam              16.3   36940048.5
# 5818             mccormick vodka pet               6.5   13125771.6
# 6501             paramount white rum               9.0   12484788.0
# 5660              malibu coconut rum              14.6   27512753.7
# 1686             canadian ltd whisky               9.4   13579854.3
# 2381                     crown royal              22.7   52737754.5
# 7510     seagrams 7 crown bl whiskey              12.2   19573085.7
# 279     absolut swedish vodka 80 prf              18.9   35706596.9
# 3376                       five star               7.0   11616547.1
#
#       state_profit     Volume
# 1106    39474773.5  3321325.4
# 4262    17564139.1  2194090.1
# 8729    29434345.9  1296265.1
# 1780    24483195.8  1150701.3
# 3374     9294191.9  1139233.3
# 3326    21789197.9  1077358.6
# 887      7218708.8   953996.0
# 6742     5642686.3   688049.3
# 4673    22407124.4   651736.4
# 331      7890455.1   599049.6
# 1747    12124035.5   549444.0
# 4840    12349841.4   512764.1
# 5818     4367443.6   512531.5
# 6501     4156943.2   482278.0
# 5660     9181071.1   479868.9
# 1686     4675692.8   470808.0
# 2381    17636977.7   466157.1
# 7510     6520205.6   459800.9
# 279     11865611.7   445003.1
# 3376     3873770.4   442873.7

# %% [markdown]
# Finally let's explore the relation between Average price per bottle, Sales, state profit and Volume sold when it comes to the 100 most sold items.

# %%
subset = subset.sort_values('Volume', ascending = False)
top100 = subset.head(100)

area = subset.Volume**(1/2)
color = subset.total_sales

subset.plot.scatter(x ='state_profit', y ='Avg_bottle_price' ,
                     c = color, colormap=matplotlib.cm.get_cmap('Spectral'),
                     s = area, edgecolors = 'k',
                     sharex=False, figsize = (15,6), alpha = 0.5)
plt.title('Profit by Average bottle price. Size is total volume sold. Color is Total Sales($)')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Heatmap

# %%
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(round(df.corr(), 2), center = 0, cmap="coolwarm", annot = True, annot_kws={'size': 10})
# Out:
# <AxesSubplot:>

# %% [markdown]
# As espected we see that State Bottle cost and Retail price are strongly correlated, similarly to Sale($) and state_profit.
# Other high correlations are:
#  * Negative correlation of -0.46 between pack size and bottle Volume: the bigger the volume, the less bottles in a pack.
#  * Negative correlation of -0.27 between pack size and bottle Cost: the bigger the pack, the less bottles cost.
#  * Positive correlation of 0.41 between bottle Volume and bottle Cost: the bigger the Bottle, the the more it will cost.
#  * Finnaly, strong positive correlations (over 0.83) between Bottles Sold, Sale, Volume Sold and State Profit.

# %% [markdown]
# ## The impact of Covid-19 on the Alcoholic Beverages Industry

# %%
df = pd.read_csv('../data/interim/pandemicEDA_df.csv')

# %%
df
# Out:
#           Unnamed: 0        Date                       Store Name  \
# 0            2414117  2016-03-24      Hillstreet News and Tobacco
# 1            2414484  2016-03-24      Hillstreet News and Tobacco
# 2            2414605  2016-03-24      Hillstreet News and Tobacco
# 3            2414652  2016-03-17      Hillstreet News and Tobacco
# 4            2415000  2016-03-24      Hillstreet News and Tobacco
# ...              ...         ...                              ...
# 21641140     4647896  2017-11-17         Cats Eye Distillery, LLC
# 21641141     4622234  2018-05-23       Green Frog Distillery, LLC
# 21641142     4610127  2018-07-26         Templeton Distilling LLC
# 21641143     2275966  2020-10-15  Rock River Distillation Company
# 21641144     2280453  2020-10-15  Rock River Distillation Company
#
#                  City      County  \
# 0         CEDAR FALLS  black hawk
# 1         CEDAR FALLS  black hawk
# 2         CEDAR FALLS  black hawk
# 3         CEDAR FALLS  black hawk
# 4         CEDAR FALLS  black hawk
# ...               ...         ...
# 21641140   Bettendorf       scott
# 21641141       Keokuk         lee
# 21641142    Templeton     carroll
# 21641143  Rock Rapids        lyon
# 21641144  Rock Rapids        lyon
#
#                                               Vendor Name  \
# 0                                         Diageo Americas
# 1                                       Sazerac Co., Inc.
# 2                        Constellation Wine Company, Inc.
# 3                                                 Proximo
# 4                                   Sazerac North America
# ...                                                   ...
# 21641140                              Cats Eye Distillery
# 21641141                       Green Frog Distillery, LLC
# 21641142                         Templeton Distilling LLC
# 21641143  Rocky Top Investments / Rock River Distillation
# 21641144  Rocky Top Investments / Rock River Distillation
#
#                                Category Name  \
# 0         MISC. IMPORTED CORDIALS & LIQUEURS
# 1                          IMPORTED SCHNAPPS
# 2                          CANADIAN WHISKIES
# 3                                    TEQUILA
# 4                             VODKA 80 PROOF
# ...                                      ...
# 21641140                       Corn Whiskies
# 21641141                       Corn Whiskies
# 21641142                    Blended Whiskies
# 21641143      Temporary & Specialty Packages
# 21641144     Temporary &  Specialty Packages
#
#                                      Item Description  Sale (Dollars)  \
# 0                      Romana Sambuca Italian Liquore          243.00
# 1                      Dr. Mcgillicuddy's Mentholmint          156.12
# 2                                        Black Velvet          477.60
# 3               Jose Cuervo Especial Reposado Tequila          450.00
# 4                                          Skol Vodka           79.56
# ...                                               ...             ...
# 21641140                      Essence of Iowa Whiskey          346.56
# 21641141  Green Frog Distillery Straight Corn Whiskey          157.50
# 21641142            Templeton Rye Special Reserve 8YR          246.72
# 21641143                                 Revenant Rye         1620.00
# 21641144                        Double Barrel Bourbon         2700.00
#
#           Volume Sold (Gallons)  state_profit
# 0                          2.38         81.00
# 1                          2.38         52.08
# 2                         12.68        159.36
# 3                          6.34        150.00
# 4                          3.17         26.52
# ...                         ...           ...
# 21641140                   0.19          9.63
# 21641141                   0.39         17.50
# 21641142                   9.70        671.79
# 21641143                   7.13        540.00
# 21641144                  11.88        900.00
#
# [21641145 rows x 11 columns]

# %% [markdown]
# We will drop the first unnecesary column that originates from the former index.

# %%
df = df.iloc[: , 1:]

# %%
for columns in ['City', 'County', 'Category Name', 'Vendor Name', 'Item Description', 'Store Name']:
    df[columns] = df[columns].str.lower()

# %%
# Inspect categorical columns
df.describe(exclude=[np.number]).T
# Out:
#                      count unique                           top     freq
# Date              21641145   2345                    2020-12-22    18002
# Store Name        21641145   2495  hy-vee #3 / bdi / des moines   181797
# City              21641145    459                    des moines  1873606
# County            21641145     99                          polk  3976377
# Vendor Name       21641145    491               diageo americas  3631610
# Category Name     21641145    112             canadian whiskies  2090073
# Item Description  21641145   9353                  black velvet   556925

# %%
# Inspect numerical columns
df.describe(include=[np.number]).T
# Out:
#                             count        mean         std      min    25%  \
# Sale (Dollars)         21641145.0  136.985590  470.601327     0.00  32.28
# Volume Sold (Gallons)  21641145.0    2.413350    8.962290     0.00   0.40
# state_profit           21641145.0   45.778322  157.291485 -2901.96  10.80
#
#                          50%     75%        max
# Sale (Dollars)         72.00  141.72  279557.28
# Volume Sold (Gallons)   1.27    2.77    3962.58
# state_profit           24.00   47.45   93225.60

# %% [markdown]
# To explore the covid impact on the Alcoholic industry in Iowa we have the folowing directions that we want to analyze:
# * a scatter plot to show the evolution of sales, volume sold and state profit per County. We will also use a Tableau Dashboard to better visualize the Counties.
# * a time series that shows the same 3 variables trends

# %% [markdown]
# ### Scatter Plots and Dashboards

# %% [markdown]
# We will first plot by **Quarter with the existing data** and then we will plot **by year with added data from Income per capita**.

# %%
subset = df[['Date', 'County', 'Sale (Dollars)', 'Volume Sold (Gallons)', 'state_profit']]

# %%
subset.loc[:,'Date'] = subset.loc[:,'Date'].apply(pd.to_datetime)
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
subset = subset.set_index('Date')
subset
# Out:
#                 County  Sale (Dollars)  Volume Sold (Gallons)  state_profit
# Date
# 2016-03-24  black hawk          243.00                   2.38         81.00
# 2016-03-24  black hawk          156.12                   2.38         52.08
# 2016-03-24  black hawk          477.60                  12.68        159.36
# 2016-03-17  black hawk          450.00                   6.34        150.00
# 2016-03-24  black hawk           79.56                   3.17         26.52
# ...                ...             ...                    ...           ...
# 2017-11-17       scott          346.56                   0.19          9.63
# 2018-05-23         lee          157.50                   0.39         17.50
# 2018-07-26     carroll          246.72                   9.70        671.79
# 2020-10-15        lyon         1620.00                   7.13        540.00
# 2020-10-15        lyon         2700.00                  11.88        900.00
#
# [21641145 rows x 4 columns]

# %%
subset.columns = ['County', 'Sale', 'Volume', 'state_profit']

# %%
grouper = subset.groupby('County').resample('Q').sum()
grouper
# Out:
#                         Sale   Volume  state_profit
# County Date
# adair  2012-03-31   78426.57  1830.92      26327.85
#        2012-06-30  110003.28  2356.82      36956.82
#        2012-09-30  101681.95  2150.68      34084.64
#        2012-12-31  123579.68  2454.28      41607.74
#        2013-03-31   82411.70  1786.17      27579.63
# ...                      ...      ...           ...
# wright 2020-06-30  263194.43  5103.59      87856.80
#        2020-09-30  233584.51  4358.62      77750.01
#        2020-12-31  221124.60  4054.50      73915.42
#        2021-03-31  231320.48  4155.41      77288.50
#        2021-06-30  214209.09  4031.90      71335.78
#
# [3762 rows x 3 columns]

# %%
grouper = grouper.reset_index()
grouper
# Out:
#       County       Date       Sale   Volume  state_profit
# 0      adair 2012-03-31   78426.57  1830.92      26327.85
# 1      adair 2012-06-30  110003.28  2356.82      36956.82
# 2      adair 2012-09-30  101681.95  2150.68      34084.64
# 3      adair 2012-12-31  123579.68  2454.28      41607.74
# 4      adair 2013-03-31   82411.70  1786.17      27579.63
# ...      ...        ...        ...      ...           ...
# 3757  wright 2020-06-30  263194.43  5103.59      87856.80
# 3758  wright 2020-09-30  233584.51  4358.62      77750.01
# 3759  wright 2020-12-31  221124.60  4054.50      73915.42
# 3760  wright 2021-03-31  231320.48  4155.41      77288.50
# 3761  wright 2021-06-30  214209.09  4031.90      71335.78
#
# [3762 rows x 5 columns]

# %% [markdown]
# ### Tableau Dashboard

# %% [markdown]
# We will group by County and export data to Tableau for a better visualization of the Counties

# %%
data_for_tableau = grouper.groupby('County').sum()
data_for_tableau = data_for_tableau.reset_index()
data_for_tableau.to_csv('../data/final/data_for_tableau.csv')

# %% [markdown]
# ![tableau_dash.PNG](attachment:tableau_dash.PNG)

# %% [markdown]
# ### Quarterly Evolution

# %%
grouper['str_Date'] = grouper['Date'].astype(str)
q_dates = grouper.str_Date.unique()

# %%
def plotquarter(date):
    data = grouper[grouper.Date == date]
    area = data.state_profit*1e-3
    color = data.state_profit*1e-6
    
    data.plot.scatter(x = 'Sale', y = 'Volume', s = area, c = color,
                     colormap = matplotlib.cm.get_cmap('cool'), linewidth = 1, edgecolors = 'k',
                      vmin = 0, vmax = 8, alpha = 0.6, sharex = False)
    plt.axis(xmax = 3e7, ymax = 400000)

# %%
interact(plotquarter, date = q_dates)
# Out:
# interactive(children=(Dropdown(description='date', options=('2012-03-31', '2012-06-30', '2012-09-30', '2012-12…
# <function __main__.plotquarter(date)>

# %% [markdown]
# ### Yearly Evolution

# %% [markdown]
# We will need to download the yearly average income per county since 2012.

# %%
income = pd.read_csv('../data/raw/Annual_Personal_Income_for_State_of_Iowa_by_County_since2012.csv')
income.head(3)
# Out:
#                        Row ID  Geography ID       Name Variable Code  \
# 0  19001_2012_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 1  19001_2013_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 2  19001_2014_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  42093       Dollars  12/31/2012
# 1  Per capita personal income  44271       Dollars  12/31/2013
# 2  Per capita personal income  44864       Dollars  12/31/2014
#
#                        Location
# 0  POINT (-94.478164 41.328528)
# 1  POINT (-94.478164 41.328528)
# 2  POINT (-94.478164 41.328528)

# %%
income['County'] = income['Name'].str[:-4]
income['County'] = income['County'].str.lower()
income.head()
# Out:
#                        Row ID  Geography ID       Name Variable Code  \
# 0  19001_2012_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 1  19001_2013_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 2  19001_2014_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 3  19001_2015_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
# 4  19001_2016_CAINC1-3_annual         19001  Adair, IA      CAINC1-3
#
#                      Variable  Value Variable Unit        Date  \
# 0  Per capita personal income  42093       Dollars  12/31/2012
# 1  Per capita personal income  44271       Dollars  12/31/2013
# 2  Per capita personal income  44864       Dollars  12/31/2014
# 3  Per capita personal income  47700       Dollars  12/31/2015
# 4  Per capita personal income  47195       Dollars  12/31/2016
#
#                        Location County
# 0  POINT (-94.478164 41.328528)  adair
# 1  POINT (-94.478164 41.328528)  adair
# 2  POINT (-94.478164 41.328528)  adair
# 3  POINT (-94.478164 41.328528)  adair
# 4  POINT (-94.478164 41.328528)  adair

# %%
income = income[['Date', 'County', 'Value']]
income = income.set_index('Date')
income
# Out:
#             County  Value
# Date
# 12/31/2012   adair  42093
# 12/31/2013   adair  44271
# 12/31/2014   adair  44864
# 12/31/2015   adair  47700
# 12/31/2016   adair  47195
# ...            ...    ...
# 12/31/2015  wright  52902
# 12/31/2016  wright  47750
# 12/31/2017  wright  49017
# 12/31/2018  wright  54438
# 12/31/2019  wright  55258
#
# [792 rows x 2 columns]

# %% [markdown]
# It seems we don't have data for 12/31/2020. for this We will use the data from 2019, and we will add/substract the mean difference between the State value for 2020 and that from 2019. Even more, we can use the data from this year to create the average income per capita for 2021.

# %% [markdown]
# This is what we found on Iowa.gov regarding per capita personal income:
# - 62,035 at 03/31/2021
# - 55,264 at 12/31/2020
# - 52,229 at 12/31/2019

# %%
dif2020_2019 = 55264 - 52229
dif2021_2019 = 62035 - 52229

# %%
print('The average income in Iowa increased from 2019 to 2020 with ',dif2020_2019,'and from 2019 to Q1 of 2021 with', dif2021_2019)
# Out:
# The average income in Iowa increased from 2019 to 2020 with  3035 and from 2019 to Q1 of 2021 with 9806

# %%
counties = income['County'].unique()

# %%
income_2020 = income.loc['12/31/2019',:]
income_2020 = income_2020.set_index('County')
income_2020 += dif2020_2019
income_2020['Date'] = '12/31/2020'
income_2020
# Out:
#             Value        Date
# County
# adair       58286  12/31/2020
# adams       69718  12/31/2020
# allamakee   52980  12/31/2020
# appanoose   43035  12/31/2020
# audubon     61394  12/31/2020
# ...           ...         ...
# winnebago   48828  12/31/2020
# winneshiek  54939  12/31/2020
# woodbury    48167  12/31/2020
# worth       47710  12/31/2020
# wright      58293  12/31/2020
#
# [99 rows x 2 columns]

# %%
income_2021 = income.loc['12/31/2019',:]
income_2021 = income_2021.set_index('County')
income_2021 += dif2021_2019
income_2021['Date'] = '12/31/2021'
income_2021
# Out:
#             Value        Date
# County
# adair       65057  12/31/2021
# adams       76489  12/31/2021
# allamakee   59751  12/31/2021
# appanoose   49806  12/31/2021
# audubon     68165  12/31/2021
# ...           ...         ...
# winnebago   55599  12/31/2021
# winneshiek  61710  12/31/2021
# woodbury    54938  12/31/2021
# worth       54481  12/31/2021
# wright      65064  12/31/2021
#
# [99 rows x 2 columns]

# %%
income_2021 = income_2021.reset_index()
income_2021 = income_2021.set_index('Date')

income_2020 = income_2020.reset_index()
income_2020 = income_2020.set_index('Date')

# %%
income = income.append(income_2020)
income = income.append(income_2021)

income
# Out:
#                 County  Value
# Date
# 12/31/2012       adair  42093
# 12/31/2013       adair  44271
# 12/31/2014       adair  44864
# 12/31/2015       adair  47700
# 12/31/2016       adair  47195
# ...                ...    ...
# 12/31/2021   winnebago  55599
# 12/31/2021  winneshiek  61710
# 12/31/2021    woodbury  54938
# 12/31/2021       worth  54481
# 12/31/2021      wright  65064
#
# [990 rows x 2 columns]

# %%
income = income.reset_index()
income
# Out:
#            Date      County  Value
# 0    12/31/2012       adair  42093
# 1    12/31/2013       adair  44271
# 2    12/31/2014       adair  44864
# 3    12/31/2015       adair  47700
# 4    12/31/2016       adair  47195
# ..          ...         ...    ...
# 985  12/31/2021   winnebago  55599
# 986  12/31/2021  winneshiek  61710
# 987  12/31/2021    woodbury  54938
# 988  12/31/2021       worth  54481
# 989  12/31/2021      wright  65064
#
# [990 rows x 3 columns]

# %%
income.loc[:,'Date'] = income.loc[:,'Date'].apply(pd.to_datetime)

# %% [markdown]
# Now let's group the subset by years and merge the average income.

# %%
per_year_data = subset.groupby('County').resample('Y').sum()
per_year_data.reset_index()
# Out:
#      County       Date       Sale    Volume  state_profit
# 0     adair 2012-12-31  413691.48   8792.70     138977.05
# 1     adair 2013-12-31  378584.26   8229.74     127025.12
# 2     adair 2014-12-31  413071.07   8817.71     138332.90
# 3     adair 2015-12-31  424750.82   8969.34     142154.58
# 4     adair 2016-12-31  444516.75   9181.33     148066.75
# ..      ...        ...        ...       ...           ...
# 985  wright 2017-12-31  761075.24  16208.98     254691.13
# 986  wright 2018-12-31  764098.98  15916.46     255105.54
# 987  wright 2019-12-31  792071.72  16177.16     264132.12
# 988  wright 2020-12-31  906035.74  17191.83     302328.34
# 989  wright 2021-12-31  445529.57   8187.31     148624.28
#
# [990 rows x 5 columns]

# %%
per_year_data = per_year_data.merge(income, how = 'left', on = ['County', 'Date'])
per_year_data
# Out:
#      County       Date       Sale    Volume  state_profit  Value
# 0     adair 2012-12-31  413691.48   8792.70     138977.05  42093
# 1     adair 2013-12-31  378584.26   8229.74     127025.12  44271
# 2     adair 2014-12-31  413071.07   8817.71     138332.90  44864
# 3     adair 2015-12-31  424750.82   8969.34     142154.58  47700
# 4     adair 2016-12-31  444516.75   9181.33     148066.75  47195
# ..      ...        ...        ...       ...           ...    ...
# 985  wright 2017-12-31  761075.24  16208.98     254691.13  49017
# 986  wright 2018-12-31  764098.98  15916.46     255105.54  54438
# 987  wright 2019-12-31  792071.72  16177.16     264132.12  55258
# 988  wright 2020-12-31  906035.74  17191.83     302328.34  58293
# 989  wright 2021-12-31  445529.57   8187.31     148624.28  65064
#
# [990 rows x 6 columns]

# %%
per_year_data.count()
# Out:
# County          990
# Date            990
# Sale            990
# Volume          990
# state_profit    990
# Value           990
# dtype: int64

# %%
per_year_data.columns = ['County','Date','Sale','Volume','state_profit','Avg_income']

# %%
per_year_data['year'] = per_year_data['Date'].dt.year

# %%
per_year_data = per_year_data.drop('Date', axis = 1)

# %%
per_year_data
# Out:
#      County       Sale    Volume  state_profit  Avg_income  year
# 0     adair  413691.48   8792.70     138977.05       42093  2012
# 1     adair  378584.26   8229.74     127025.12       44271  2013
# 2     adair  413071.07   8817.71     138332.90       44864  2014
# 3     adair  424750.82   8969.34     142154.58       47700  2015
# 4     adair  444516.75   9181.33     148066.75       47195  2016
# ..      ...        ...       ...           ...         ...   ...
# 985  wright  761075.24  16208.98     254691.13       49017  2017
# 986  wright  764098.98  15916.46     255105.54       54438  2018
# 987  wright  792071.72  16177.16     264132.12       55258  2019
# 988  wright  906035.74  17191.83     302328.34       58293  2020
# 989  wright  445529.57   8187.31     148624.28       65064  2021
#
# [990 rows x 6 columns]

# %%
def plotyear(year):
    data = per_year_data[per_year_data['year'] == year]
    area = data.Volume*1e-3
    color = data.state_profit*1e-6
    
    data.plot.scatter(x = 'Avg_income', y = 'Sale', s = area, c = color,
                     colormap = matplotlib.cm.get_cmap('cool'), linewidth = 1, edgecolors = 'k',
                      vmin = 0, vmax = 8, alpha = 0.6, sharex = False)
    plt.axis(xmin = 20000, ymin = -1000000, xmax = 80000, ymax = 1e8)

# %%
plotyear(2019)

# %%
interact(plotyear, year = widgets.IntSlider(min = 2012, max = 2021, step = 1, value = 2020))
# Out:
# interactive(children=(IntSlider(value=2020, description='year', max=2021, min=2012), Output()), _dom_classes=(…
# <function __main__.plotyear(year)>

# %% [markdown]
# For one, we can observe an clear increase in teh average income per capita. With it, we can obserrve a similar increase in the liquor Sales and with it, in Volume sold and profit produced.

# %% [markdown]
# ## Time Series

# %% [markdown]
# Finaly, let's explore these trends in a timeseries plots. This time we will mark the start of the COVID-19 Pandemic and we will have a closer look at the data starting with 2020.

# %%
df_ts = df[['Date','Sale (Dollars)']]
df_ts
# Out:
#                 Date  Sale (Dollars)
# 0         2016-03-24          243.00
# 1         2016-03-24          156.12
# 2         2016-03-24          477.60
# 3         2016-03-17          450.00
# 4         2016-03-24           79.56
# ...              ...             ...
# 21641140  2017-11-17          346.56
# 21641141  2018-05-23          157.50
# 21641142  2018-07-26          246.72
# 21641143  2020-10-15         1620.00
# 21641144  2020-10-15         2700.00
#
# [21641145 rows x 2 columns]

# %%
df_ts = df_ts.groupby('Date').sum()
df_ts
# Out:
#             Sale (Dollars)
# Date
# 2012-01-03      1012493.81
# 2012-01-04       860053.73
# 2012-01-05       940194.93
# 2012-01-09       933835.50
# 2012-01-10       900077.61
# ...                    ...
# 2021-06-25      1728571.09
# 2021-06-27        42796.55
# 2021-06-28      1951596.50
# 2021-06-29      1615266.23
# 2021-06-30      1726026.26
#
# [2345 rows x 1 columns]

# %%
df_ts.index = pd.to_datetime(df_ts.index)

# %%
df_ts.plot()
plt.axvline(x='2013-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2014-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2015-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2016-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2017-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2018-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2019-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2020-01-01',linestyle = '--', color = 'r')
plt.axvline(x='2021-01-01',linestyle = '--', color = 'r')

# %%
df_ts.resample('W').sum().plot(color = 'cyan')
plt.title('Weekly trends')
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.legend()
df_ts.resample('M').sum().plot(color = 'black')
plt.title('Monthly trends')
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.legend()
df_ts.resample('Q').sum().plot()
plt.title('Quarterly trends')
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.legend()

# %% [markdown]
# Let's see if the income or population impacted this trend.

# %%
population = pd.read_csv('../data/raw/Iowa_PopulationEstimate.csv', parse_dates = True)
population
# Out:
#   Geography Id   Type  Name     Variable Data Collection Period  \
# 0  0400000US19  state  Iowa  B02001_001E              2008-2012
# 1  0400000US19  state  Iowa  B02001_001E              2015-2019
# 2  0400000US19  state  Iowa  B02001_001E              2011-2015
# 3  0400000US19  state  Iowa  B02001_001E              2012-2016
# 4  0400000US19  state  Iowa  B02001_001E              2014-2018
# 5  0400000US19  state  Iowa  B02001_001E              2010-2014
# 6  0400000US19  state  Iowa  B02001_001E              2013-2017
# 7  0400000US19  state  Iowa  B02001_001E              2009-2013
#
#   Data Collection End Date   Race  Population Estimate  Change Rate  \
# 0               12/31/2012  Total              3047646          NaN
# 1               12/31/2019  Total              3139508         0.02
# 2               12/31/2015  Total              3093526          NaN
# 3               12/31/2016  Total              3106589          NaN
# 4               12/31/2018  Total              3132499         0.02
# 5               12/31/2014  Total              3078116          NaN
# 6               12/31/2017  Total              3118102         0.02
# 7               12/31/2013  Total              3062553          NaN
#
#    Value Change                        Location  \
# 0           NaN  POINT (-93.4933473 42.0700243)
# 1       61392.0  POINT (-93.4933473 42.0700243)
# 2           NaN  POINT (-93.4933473 42.0700243)
# 3           NaN  POINT (-93.4933473 42.0700243)
# 4       69946.0  POINT (-93.4933473 42.0700243)
# 5           NaN  POINT (-93.4933473 42.0700243)
# 6       70456.0  POINT (-93.4933473 42.0700243)
# 7           NaN  POINT (-93.4933473 42.0700243)
#
#   Previous Data Collection Period
# 0                       2003-2007
# 1                       2010-2014
# 2                       2006-2010
# 3                       2007-2011
# 4                       2009-2013
# 5                       2005-2009
# 6                       2008-2012
# 7                       2004-2008

# %%
population = population[['Population Estimate', 'Data Collection End Date']]

# %%
q_income = pd.read_csv('../data/raw/Quarterly_Personal_Income_for_State_of_Iowa.csv', parse_dates = True)
q_income
# Out:
#                            Row ID Table Code       Table Name Variable Code  \
# 0   19000_2012Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 1   19000_2012Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 2   19000_2013Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 3   19000_2013Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 4   19000_2013Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 5   19000_2013Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 6   19000_2014Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 7   19000_2014Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 8   19000_2014Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 9   19000_2014Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 10  19000_2015Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 11  19000_2015Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 12  19000_2015Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 13  19000_2015Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 14  19000_2016Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 15  19000_2016Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 16  19000_2016Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 17  19000_2016Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 18  19000_2017Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 19  19000_2017Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 20  19000_2017Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 21  19000_2017Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 22  19000_2018Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 23  19000_2018Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 24  19000_2018Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 25  19000_2018Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 26  19000_2019Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 27  19000_2019Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 28  19000_2019Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 29  19000_2019Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 30  19000_2020Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 31  19000_2020Q2_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 32  19000_2020Q3_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 33  19000_2020Q4_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
# 34  19000_2021Q1_SQINC1-3_quarter     SQINC1  Personal Income      SQINC1-3
#
#                       Variable  Value Variable Unit        Date
# 0   Per capita personal income  42573       Dollars  09/30/2012
# 1   Per capita personal income  43582       Dollars  12/31/2012
# 2   Per capita personal income  43306       Dollars  03/31/2013
# 3   Per capita personal income  43486       Dollars  06/30/2013
# 4   Per capita personal income  43666       Dollars  09/30/2013
# 5   Per capita personal income  43365       Dollars  12/31/2013
# 6   Per capita personal income  43812       Dollars  03/31/2014
# 7   Per capita personal income  44840       Dollars  06/30/2014
# 8   Per capita personal income  45075       Dollars  09/30/2014
# 9   Per capita personal income  45404       Dollars  12/31/2014
# 10  Per capita personal income  45886       Dollars  03/31/2015
# 11  Per capita personal income  46027       Dollars  06/30/2015
# 12  Per capita personal income  46516       Dollars  09/30/2015
# 13  Per capita personal income  46653       Dollars  12/31/2015
# 14  Per capita personal income  46326       Dollars  03/31/2016
# 15  Per capita personal income  46380       Dollars  06/30/2016
# 16  Per capita personal income  46701       Dollars  09/30/2016
# 17  Per capita personal income  46650       Dollars  12/31/2016
# 18  Per capita personal income  47340       Dollars  03/31/2017
# 19  Per capita personal income  47529       Dollars  06/30/2017
# 20  Per capita personal income  47503       Dollars  09/30/2017
# 21  Per capita personal income  48150       Dollars  12/31/2017
# 22  Per capita personal income  49208       Dollars  03/31/2018
# 23  Per capita personal income  49855       Dollars  06/30/2018
# 24  Per capita personal income  50213       Dollars  09/30/2018
# 25  Per capita personal income  51290       Dollars  12/31/2018
# 26  Per capita personal income  51440       Dollars  03/31/2019
# 27  Per capita personal income  51281       Dollars  06/30/2019
# 28  Per capita personal income  52213       Dollars  09/30/2019
# 29  Per capita personal income  52229       Dollars  12/31/2019
# 30  Per capita personal income  52820       Dollars  03/31/2020
# 31  Per capita personal income  58407       Dollars  06/30/2020
# 32  Per capita personal income  54371       Dollars  09/30/2020
# 33  Per capita personal income  55264       Dollars  12/31/2020
# 34  Per capita personal income  62035       Dollars  03/31/2021

# %%
q_income = q_income[['Date', 'Value']]

# %%
df_ts_q = df_ts.resample('Q').sum()

# %%
population = population.set_index('Data Collection End Date')
population.index = pd.to_datetime(population.index)

# %%
q_income = q_income.set_index('Date')
q_income.index = pd.to_datetime(q_income.index)

# %%
population.plot()
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.title('Population trends(annual)')
plt.legend()

# %%
view = q_income['2020-03-11':]

q_income.plot()
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.title('Income trends(quarterly)')
plt.legend(loc='lower right')

plt.axes([0.20, 0.50, 0.30, 0.30])
plt.plot(view, color = 'red')
plt.title('During Covid-19')
# Out:
# Text(0.5, 1.0, 'During Covid-19')

# %%
view = df_ts_q['2020-03-11':]

df_ts_q.plot()
plt.axvline(x='2020-03-11',linestyle = '--', color = 'g', label = 'Covid-19 becomes a Pandemic')
plt.title('Sales trends(quarterly)')
plt.legend(loc='lower right')

plt.axes([0.15, 0.58, 0.35, 0.30])
plt.plot(view, color = 'red')
plt.title('During Covid-19')
# Out:
# Text(0.5, 1.0, 'During Covid-19')

# %% [markdown]
# The total population seems irrelevant to the Business problem we are looking after: the impact of Covid-19 on the industry.
#
#
#
# But the other 2 quarterly graphs are quite telling.
#
#
#
# Let's explore the Income first.
#
#
#
#  - For the average income, we can see a big jump by more than 5.000 USD from Q1 to Q2 of 2020, right after Covid-19 was declared a pandemic and Pandemic Stimulus was send to businesses and to all US residents. Before this, it took a whole 3 years for the average income to increase by 5000 USD.
#  - Next, we can see the income dropping suddenly, back to where the income trend from the previous quarters would have predict the income to be.
#  - The evolution from Q3 to Q4 of 2020 was also the expected one.
#  - And lastly, we observe another big jump of more than 5000 USD from Q1 of 2021 to Q2 of 2021. That was probably associated as well with a stimulus check awarded by the US Government.

# %% [markdown]
# Regarding the Sales amount, we can observe a general pre-pandemic trend:
#
#    * Q1 is a bad quarter for sales
#    * then we see a big jump in Q2
#    * Q3 is slightly worse than Q2
#    * another big jump in Q4
#    * followed by a big regression from Q4 to Q1 of next year.
#
# We can explain these by the fact that in Q4 there are a lof of holidays, when people are going to parties and gatherings.
#
# But for 2020 we see something different:
# 1. the jump from Q1 to Q2 in 2020 was so high that the Sales in Q2 were higher than those of Q4 the previous year. This has not happened in any of the previous 8 years.
#
# 2. the valley that was ussualy between Q2 and Q3 was now gone, and the sales continued on an ascendent trend from Q2 to Q3 and then to Q4. And this happened with a lot of restrictions to bars and restaurant because ofn Covid-19.

# %% [markdown]
# To conclude our short analysis, there are certain correlations between the Pandemic and the growth in the Beverages industry. This growth might as well be explained by the fact that the average income increased as well during the same period.
